# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.compat.v1.enable_eager_execution()


import random
import gym
import numpy as np
from collections import deque
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import pylab
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10
import os

ENV_NAME = "CartPole-v1"

GAMMA = 0.1
LEARNING_RATE = 0.001

MEMORY_SIZE = 100000
MIN_MEMORY_SIZE = 200
BATCH_SIZE = 64

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.9995

from environment.environment import GridWorld

now = '30x40_8POI'

filling = True
scores = []
averages = []
episodes = []

debug_mode = False
show_graph_every = 1
means = False
resume = False


env = GridWorld(show_graph_every, debug_mode, means)


size = 1200



class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX
        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)
        if resume:
            self.model = keras.models.load_model('models/'+now+'.h5', custom_objects=None, compile=True)
            print('Model loaded')
            self.exploration_rate = EXPLORATION_MAX
            self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))
            return
        self.model = Sequential()
        self.model.add(Dense(size, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(size, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))
        print('Model created')

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):        
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def save(self):
        self.model.save('models/'+now+'.h5')   
        print('model saved')
    
    def experience_replay(self, run):
        if len(self.memory) < MIN_MEMORY_SIZE:
            return
        global filling
        filling = False
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)                
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)


def cartpole():
    env = GridWorld(show_graph_every, debug_mode, means)
    #observation_space = env.observation_space.shape[0]
    action_space = 6
    observation_space = size
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            action = dqn_solver.act(state)
            observe_past, reward, total_reward, state_next, terminal = env.step(action)
            #reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal or (not filling and step == 20):
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate)[:4] + ", score: " + str(total_reward)[:4] + ' step: '+ str(step))
                PlotModel(total_reward, run)                
                break
            dqn_solver.experience_replay(run)
        if run % 20 == 0:
            dqn_solver.save()



def cartpole_test():
    #observation_space = env.observation_space.shape[0]
    global show_graph_every
    show_graph_every = 1
    env = GridWorld(show_graph_every, debug_mode, means)
    action_space = 5
    observation_space = size
    model = keras.models.load_model('models/'+now+'.h5', custom_objects=None, compile=True)
    print('Model loaded')
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            action = np.argmax(model.predict(state)[0])
            observe_past, reward, total_reward, state_next, terminal = env.step(action)
            state_next = np.reshape(state_next, [1, observation_space])
            state = state_next
            if terminal:
                print ("Test: " + str(run) + ", score: " + str(total_reward)[:4] + ' step: '+ str(step))
                break            
            
            
            
            
            
def PlotModel(score, episode_number):
    scores.append(score)
    averages.append(sum(scores[-50:]) / len(scores[-50:]))
    episodes.append(episode_number)
    pylab.plot(episodes, scores, 'b')
    pylab.plot(episodes, averages, 'r')
    pylab.ylabel('Score', fontsize=18)
    pylab.xlabel('Games', fontsize=18)
    file_name = "breakout_model_{}".format(now)
    name = file_name + '.png'
    try:
        if not os.path.exists('training_images'): os.makedirs('training_images')
        pylab.savefig('training_images/'+name)

    except OSError as e:
        print(e)
        pass
    return    
            
            
            
            
            
            
            
            
            
            
            
            
            

if __name__ == "__main__":
    #cartpole()
    cartpole_test()
# Out:
# WARNING:tensorflow:From /home/lorenzo/anaconda3/envs/lorenzo_env/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Using TensorFlow backend.
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Model loaded
# Test: 1, score: 42.5 step: 20
# Test: 2, score: 40.3 step: 10
# Test: 3, score: 40.3 step: 10
# Test: 4, score: 40.3 step: 10
# Test: 5, score: 40.3 step: 10
# Test: 6, score: 40.3 step: 10
# Test: 7, score: 40.3 step: 10
# Test: 8, score: 40.3 step: 10
# Test: 9, score: 42.5 step: 20
# Test: 10, score: 42.5 step: 20
# Test: 11, score: 40.3 step: 10
# Test: 12, score: 42.5 step: 20
# Test: 13, score: 40.3 step: 10
# Test: 14, score: 40.3 step: 10
# Test: 15, score: 42.5 step: 20
# Test: 16, score: 40.3 step: 10
# Test: 17, score: 40.3 step: 10
# Test: 18, score: 40.3 step: 10
# Test: 19, score: 40.3 step: 10
# Test: 20, score: 40.3 step: 10
# Test: 21, score: 40.3 step: 10
# Test: 22, score: 40.3 step: 10
# Test: 23, score: 40.3 step: 10
# Test: 24, score: 42.5 step: 20
# Test: 25, score: 42.5 step: 20
# Test: 26, score: 42.5 step: 20
# Test: 27, score: 40.3 step: 10
# Test: 28, score: 42.5 step: 20
# Test: 29, score: 40.3 step: 10
# Test: 30, score: 40.3 step: 10
# Test: 31, score: 42.5 step: 20
# Test: 32, score: 42.5 step: 20
# Test: 33, score: 40.3 step: 10
# Test: 34, score: 40.3 step: 10
# Test: 35, score: 42.5 step: 20
# Test: 36, score: 40.3 step: 10
# Test: 37, score: 40.3 step: 10
# Test: 38, score: 42.5 step: 20
# Test: 39, score: 40.3 step: 10
# Test: 40, score: 40.3 step: 10
# Test: 41, score: 40.3 step: 10
# Test: 42, score: 40.3 step: 10
# Test: 43, score: 40.3 step: 10
# Test: 44, score: 40.3 step: 10
# Test: 45, score: 40.3 step: 10
# Test: 46, score: 42.5 step: 20
# Test: 47, score: 42.5 step: 20
# Test: 48, score: 42.5 step: 20
# Test: 49, score: 40.3 step: 10
# Test: 50, score: 40.3 step: 10
# Test: 51, score: 40.3 step: 10
# Test: 52, score: 40.3 step: 10
# Test: 53, score: 40.3 step: 10
# Test: 54, score: 40.3 step: 10
# Test: 55, score: 40.3 step: 10
# Test: 56, score: 40.3 step: 10
# Test: 57, score: 42.5 step: 20
# Test: 58, score: 40.3 step: 10
# Test: 59, score: 40.3 step: 10
# Test: 60, score: 42.5 step: 20
# Test: 61, score: 40.3 step: 10
# Test: 62, score: 40.3 step: 10
# Test: 63, score: 42.5 step: 20
# Test: 64, score: 40.3 step: 10
# Test: 65, score: 42.5 step: 20
# Test: 66, score: 42.5 step: 20
# Test: 67, score: 42.5 step: 20
# Test: 68, score: 40.3 step: 10
# Test: 69, score: 40.3 step: 10
# Test: 70, score: 40.3 step: 10
# Test: 71, score: 40.3 step: 10
# Test: 72, score: 42.5 step: 20
# Test: 73, score: 42.5 step: 20
# Test: 74, score: 40.3 step: 10
# Test: 75, score: 40.3 step: 10
# Test: 76, score: 40.3 step: 10
# Test: 77, score: 40.3 step: 10
# Test: 78, score: 40.3 step: 10
# Test: 79, score: 40.3 step: 10
# Test: 80, score: 40.3 step: 10
# Test: 81, score: 40.3 step: 10
# Test: 82, score: 40.3 step: 10
# Test: 83, score: 42.5 step: 20
# Test: 84, score: 40.3 step: 10
# Test: 85, score: 40.3 step: 10
# Test: 86, score: 40.3 step: 10
# Test: 87, score: 40.3 step: 10
# Test: 88, score: 40.3 step: 10
# Test: 89, score: 40.3 step: 10
# Test: 90, score: 40.3 step: 10
# Test: 91, score: 42.5 step: 20
# Test: 92, score: 40.3 step: 10
# Test: 93, score: 40.3 step: 10
# Test: 94, score: 40.3 step: 10
# Test: 95, score: 42.5 step: 20
# Test: 96, score: 42.5 step: 20
# Test: 97, score: 42.5 step: 20
# Test: 98, score: 40.3 step: 10
# Test: 99, score: 40.3 step: 10
# Test: 100, score: 40.3 step: 10
# Test: 101, score: 40.3 step: 10
# Test: 102, score: 40.3 step: 10
# Test: 103, score: 42.5 step: 20
# Test: 104, score: 40.3 step: 10
# Test: 105, score: 42.5 step: 20
# Test: 106, score: 40.3 step: 10
# Test: 107, score: 40.3 step: 10
# Test: 108, score: 40.3 step: 10
# Test: 109, score: 40.3 step: 10
# Test: 110, score: 40.3 step: 10
# Test: 111, score: 40.3 step: 10
# Test: 112, score: 40.3 step: 10
# Test: 113, score: 40.3 step: 10
# Test: 114, score: 40.3 step: 10
# Test: 115, score: 40.3 step: 10
# Test: 116, score: 40.3 step: 10
# Test: 117, score: 40.3 step: 10
# Test: 118, score: 42.5 step: 20
# Test: 119, score: 40.3 step: 10
# Test: 120, score: 40.3 step: 10
# Test: 121, score: 42.5 step: 20
# Test: 122, score: 42.5 step: 20
# Test: 123, score: 40.3 step: 10
# Test: 124, score: 40.3 step: 10
# Test: 125, score: 40.3 step: 10
# Test: 126, score: 40.3 step: 10
# Test: 127, score: 40.3 step: 10
# Test: 128, score: 42.5 step: 20
# Test: 129, score: 40.3 step: 10
# Test: 130, score: 40.3 step: 10
# Test: 131, score: 40.3 step: 10
# Test: 132, score: 40.3 step: 10
# Test: 133, score: 42.5 step: 20
# Test: 134, score: 40.3 step: 10
# Test: 135, score: 42.5 step: 20
# Test: 136, score: 40.3 step: 10
# Test: 137, score: 42.5 step: 20
# Test: 138, score: 40.3 step: 10
# Test: 139, score: 42.5 step: 20
# Test: 140, score: 40.3 step: 10
# Test: 141, score: 40.3 step: 10
# Test: 142, score: 40.3 step: 10
# Test: 143, score: 40.3 step: 10
# Test: 144, score: 42.5 step: 20
# Test: 145, score: 42.5 step: 20
# Test: 146, score: 42.5 step: 20
# Test: 147, score: 40.3 step: 10
# Test: 148, score: 40.3 step: 10
# Test: 149, score: 40.3 step: 10
# Test: 150, score: 40.3 step: 10
# Test: 151, score: 40.3 step: 10
# Test: 152, score: 40.3 step: 10
# Test: 153, score: 40.3 step: 10
# Test: 154, score: 40.3 step: 10
# Test: 155, score: 40.3 step: 10
# Test: 156, score: 40.3 step: 10
# Test: 157, score: 42.5 step: 20
# Test: 158, score: 42.5 step: 20
# Test: 159, score: 40.3 step: 10
# Test: 160, score: 40.3 step: 10
# Test: 161, score: 42.5 step: 20
# Test: 162, score: 40.3 step: 10
# Test: 163, score: 42.5 step: 20
# Test: 164, score: 40.3 step: 10
# Test: 165, score: 40.3 step: 10
# Test: 166, score: 40.3 step: 10
# Test: 167, score: 40.3 step: 10
# Test: 168, score: 40.3 step: 10
# Test: 169, score: 40.3 step: 10
# Test: 170, score: 40.3 step: 10
# Test: 171, score: 40.3 step: 10
# Test: 172, score: 42.5 step: 20
# Test: 173, score: 40.3 step: 10
# Test: 174, score: 40.3 step: 10
# Test: 175, score: 42.5 step: 20
# Test: 176, score: 40.3 step: 10
# Test: 177, score: 40.3 step: 10
# Test: 178, score: 40.3 step: 10
# Test: 179, score: 40.3 step: 10
# Test: 180, score: 40.3 step: 10
# Test: 181, score: 40.3 step: 10
# Test: 182, score: 40.3 step: 10
# Test: 183, score: 40.3 step: 10
# Test: 184, score: 40.3 step: 10
# Test: 185, score: 40.3 step: 10
# Test: 186, score: 40.3 step: 10
# Test: 187, score: 40.3 step: 10
# Test: 188, score: 40.3 step: 10
# Test: 189, score: 40.3 step: 10
# Test: 190, score: 40.3 step: 10
# Test: 191, score: 40.3 step: 10
# Test: 192, score: 40.3 step: 10
# Test: 193, score: 40.3 step: 10
# Test: 194, score: 40.3 step: 10
# Test: 195, score: 40.3 step: 10
# Test: 196, score: 40.3 step: 10
# Test: 197, score: 40.3 step: 10
# Test: 198, score: 40.3 step: 10
# Test: 199, score: 40.3 step: 10
# Test: 200, score: 40.3 step: 10
# Test: 201, score: 40.3 step: 10
# Test: 202, score: 40.3 step: 10
# Test: 203, score: 40.3 step: 10
# Test: 204, score: 42.5 step: 20
# Test: 205, score: 40.3 step: 10
# Test: 206, score: 40.3 step: 10
# Test: 207, score: 42.5 step: 20
# Test: 208, score: 42.5 step: 20
# Test: 209, score: 40.3 step: 10
# Test: 210, score: 40.3 step: 10
# Test: 211, score: 42.5 step: 20
# Test: 212, score: 40.3 step: 10
# Test: 213, score: 40.3 step: 10
# Test: 214, score: 40.3 step: 10
# Test: 215, score: 40.3 step: 10
# Test: 216, score: 40.3 step: 10
# Test: 217, score: 40.3 step: 10
# Test: 218, score: 40.3 step: 10
# Test: 219, score: 40.3 step: 10
# Test: 220, score: 40.3 step: 10
# Test: 221, score: 40.3 step: 10
# Test: 222, score: 42.5 step: 20
# Test: 223, score: 40.3 step: 10
# Test: 224, score: 40.3 step: 10
# Test: 225, score: 40.3 step: 10
# Test: 226, score: 42.5 step: 20
# Test: 227, score: 40.3 step: 10
# Test: 228, score: 40.3 step: 10
# Test: 229, score: 40.3 step: 10
# Test: 230, score: 40.3 step: 10
# Test: 231, score: 40.3 step: 10
# Test: 232, score: 40.3 step: 10
# Test: 233, score: 40.3 step: 10
# Test: 234, score: 40.3 step: 10
# Test: 235, score: 42.5 step: 20
# Test: 236, score: 40.3 step: 10
# Test: 237, score: 40.3 step: 10
# Test: 238, score: 40.3 step: 10
# Test: 239, score: 40.3 step: 10
# Test: 240, score: 40.3 step: 10
# Test: 241, score: 40.3 step: 10
# Test: 242, score: 40.3 step: 10
# Test: 243, score: 40.3 step: 10
# Test: 244, score: 40.3 step: 10
# Test: 245, score: 42.5 step: 20
# Test: 246, score: 40.3 step: 10
# Test: 247, score: 40.3 step: 10
# Test: 248, score: 40.3 step: 10
# Test: 249, score: 40.3 step: 10
# Test: 250, score: 42.5 step: 20
# Test: 251, score: 40.3 step: 10
# Test: 252, score: 40.3 step: 10
# Test: 253, score: 42.5 step: 20
# Test: 254, score: 42.5 step: 20
# Test: 255, score: 40.3 step: 10
# Test: 256, score: 40.3 step: 10
# Test: 257, score: 42.5 step: 20
# Test: 258, score: 40.3 step: 10
# Test: 259, score: 40.3 step: 10
# Test: 260, score: 40.3 step: 10
# Test: 261, score: 42.5 step: 20
# Test: 262, score: 42.5 step: 20
# Test: 263, score: 42.5 step: 20
# Test: 264, score: 40.3 step: 10
# Test: 265, score: 40.3 step: 10
# Test: 266, score: 42.5 step: 20
# Test: 267, score: 42.5 step: 20
# Test: 268, score: 42.5 step: 20
# Test: 269, score: 40.3 step: 10
# Test: 270, score: 42.5 step: 20
# Test: 271, score: 40.3 step: 10
# Test: 272, score: 42.5 step: 20
# Test: 273, score: 40.3 step: 10
# Test: 274, score: 40.3 step: 10
# Test: 275, score: 40.3 step: 10
# Test: 276, score: 40.3 step: 10
# Test: 277, score: 40.3 step: 10
# Test: 278, score: 40.3 step: 10
# Test: 279, score: 40.3 step: 10
# Test: 280, score: 40.3 step: 10
# Test: 281, score: 42.5 step: 20
# Test: 282, score: 40.3 step: 10
# Test: 283, score: 40.3 step: 10
# Test: 284, score: 40.3 step: 10
# Test: 285, score: 42.5 step: 20
# Test: 286, score: 40.3 step: 10
# Test: 287, score: 42.5 step: 20
# Test: 288, score: 42.5 step: 20
# Test: 289, score: 40.3 step: 10
# Test: 290, score: 40.3 step: 10
# Test: 291, score: 40.3 step: 10
# Test: 292, score: 40.3 step: 10
# Test: 293, score: 42.5 step: 20
# Test: 294, score: 40.3 step: 10
# Test: 295, score: 42.5 step: 20
# Test: 296, score: 40.3 step: 10
# Test: 297, score: 40.3 step: 10
# Test: 298, score: 40.3 step: 10
# Test: 299, score: 40.3 step: 10
# Test: 300, score: 42.5 step: 20
# Test: 301, score: 40.3 step: 10
# Test: 302, score: 42.5 step: 20
# Test: 303, score: 40.3 step: 10
# Test: 304, score: 42.5 step: 20
# Test: 305, score: 40.3 step: 10
# Test: 306, score: 40.3 step: 10
# Test: 307, score: 40.3 step: 10
# Test: 308, score: 40.3 step: 10
# Test: 309, score: 40.3 step: 10
# Test: 310, score: 40.3 step: 10
# Test: 311, score: 40.3 step: 10
# Test: 312, score: 40.3 step: 10
# Test: 313, score: 42.5 step: 20
# Test: 314, score: 40.3 step: 10
# Test: 315, score: 40.3 step: 10
# Test: 316, score: 40.3 step: 10
# Test: 317, score: 40.3 step: 10
# Test: 318, score: 42.5 step: 20
# Test: 319, score: 40.3 step: 10
# Test: 320, score: 42.5 step: 20
# Test: 321, score: 40.3 step: 10
# Test: 322, score: 42.5 step: 20
# Test: 323, score: 40.3 step: 10
# Test: 324, score: 40.3 step: 10
# Test: 325, score: 40.3 step: 10
# Test: 326, score: 40.3 step: 10
# Test: 327, score: 40.3 step: 10
# Test: 328, score: 40.3 step: 10
# Test: 329, score: 40.3 step: 10
# Test: 330, score: 40.3 step: 10
# Test: 331, score: 42.5 step: 20
# Test: 332, score: 42.5 step: 20
# Test: 333, score: 40.3 step: 10
# Test: 334, score: 40.3 step: 10
# Test: 335, score: 40.3 step: 10
# Test: 336, score: 40.3 step: 10
# Test: 337, score: 40.3 step: 10
# Test: 338, score: 40.3 step: 10
# Test: 339, score: 40.3 step: 10
# Test: 340, score: 40.3 step: 10
# Test: 341, score: 40.3 step: 10
# Test: 342, score: 42.5 step: 20
# Test: 343, score: 40.3 step: 10
# Test: 344, score: 40.3 step: 10
# Test: 345, score: 40.3 step: 10
# Test: 346, score: 40.3 step: 10
# Test: 347, score: 40.3 step: 10
# Test: 348, score: 40.3 step: 10
# Test: 349, score: 40.3 step: 10
# Test: 350, score: 40.3 step: 10
# Test: 351, score: 40.3 step: 10
# Test: 352, score: 40.3 step: 10
# Test: 353, score: 42.5 step: 20
# Test: 354, score: 40.3 step: 10
# Test: 355, score: 42.5 step: 20
# Test: 356, score: 40.3 step: 10
# Test: 357, score: 40.3 step: 10
# Test: 358, score: 40.3 step: 10
# Test: 359, score: 40.3 step: 10
# Test: 360, score: 40.3 step: 10
# Test: 361, score: 40.3 step: 10
# Test: 362, score: 42.5 step: 20
# Test: 363, score: 42.5 step: 20
# Test: 364, score: 40.3 step: 10
# Test: 365, score: 40.3 step: 10
# Test: 366, score: 40.3 step: 10
# Test: 367, score: 42.5 step: 20
# Test: 368, score: 40.3 step: 10
# Test: 369, score: 40.3 step: 10
# Test: 370, score: 40.3 step: 10
# Test: 371, score: 42.5 step: 20
# Test: 372, score: 42.5 step: 20
# Test: 373, score: 40.3 step: 10
# Test: 374, score: 40.3 step: 10
# Test: 375, score: 40.3 step: 10
# Test: 376, score: 40.3 step: 10
# Test: 377, score: 40.3 step: 10
# Test: 378, score: 42.5 step: 20
# Test: 379, score: 40.3 step: 10
# Test: 380, score: 40.3 step: 10
# Test: 381, score: 40.3 step: 10
# Test: 382, score: 40.3 step: 10
# Test: 383, score: 42.5 step: 20
# Test: 384, score: 40.3 step: 10
# Test: 385, score: 40.3 step: 10
# Test: 386, score: 40.3 step: 10
# Test: 387, score: 42.5 step: 20
# Test: 388, score: 42.5 step: 20
# Test: 389, score: 40.3 step: 10
# Test: 390, score: 42.5 step: 20
# Test: 391, score: 40.3 step: 10
# Test: 392, score: 42.5 step: 20
# Test: 393, score: 40.3 step: 10
# Test: 394, score: 40.3 step: 10
# Test: 395, score: 40.3 step: 10
# Test: 396, score: 40.3 step: 10
# Test: 397, score: 42.5 step: 20
# Test: 398, score: 40.3 step: 10
# Test: 399, score: 40.3 step: 10
# Test: 400, score: 42.5 step: 20
# Test: 401, score: 42.5 step: 20
# Test: 402, score: 40.3 step: 10
# Test: 403, score: 40.3 step: 10
# Test: 404, score: 42.5 step: 20
# Test: 405, score: 40.3 step: 10
# Test: 406, score: 42.5 step: 20
# Test: 407, score: 40.3 step: 10
# Test: 408, score: 40.3 step: 10
# Test: 409, score: 40.3 step: 10
# Test: 410, score: 40.3 step: 10
# Test: 411, score: 42.5 step: 20
# Test: 412, score: 40.3 step: 10
# Test: 413, score: 40.3 step: 10
# Test: 414, score: 40.3 step: 10
# Test: 415, score: 40.3 step: 10
# Test: 416, score: 40.3 step: 10
# Test: 417, score: 42.5 step: 20
# Test: 418, score: 40.3 step: 10
# Test: 419, score: 40.3 step: 10
# Test: 420, score: 42.5 step: 20
# Test: 421, score: 40.3 step: 10
# Test: 422, score: 42.5 step: 20
# Test: 423, score: 40.3 step: 10
# Test: 424, score: 40.3 step: 10
# Test: 425, score: 42.5 step: 20
# Test: 426, score: 42.5 step: 20
# Test: 427, score: 42.5 step: 20
# Test: 428, score: 42.5 step: 20
# Test: 429, score: 40.3 step: 10
# Test: 430, score: 40.3 step: 10
# Test: 431, score: 42.5 step: 20
# Test: 432, score: 40.3 step: 10
# Test: 433, score: 40.3 step: 10
# Test: 434, score: 40.3 step: 10
# Test: 435, score: 40.3 step: 10
# Test: 436, score: 40.3 step: 10
# Test: 437, score: 42.5 step: 20
# Test: 438, score: 42.5 step: 20
# Test: 439, score: 40.3 step: 10
# Test: 440, score: 40.3 step: 10
# Test: 441, score: 40.3 step: 10
# Test: 442, score: 40.3 step: 10
# Test: 443, score: 40.3 step: 10
# Test: 444, score: 42.5 step: 20
# Test: 445, score: 40.3 step: 10
# Test: 446, score: 40.3 step: 10
# Test: 447, score: 40.3 step: 10
# Test: 448, score: 40.3 step: 10
# Test: 449, score: 40.3 step: 10
# Test: 450, score: 40.3 step: 10
# Test: 451, score: 40.3 step: 10
# Test: 452, score: 40.3 step: 10
# Test: 453, score: 40.3 step: 10
# Test: 454, score: 40.3 step: 10
# Test: 455, score: 40.3 step: 10
# Test: 456, score: 40.3 step: 10
# Test: 457, score: 42.5 step: 20
# Test: 458, score: 40.3 step: 10
# Test: 459, score: 40.3 step: 10
# Test: 460, score: 40.3 step: 10
# Test: 461, score: 40.3 step: 10
# Test: 462, score: 40.3 step: 10
# Test: 463, score: 40.3 step: 10
# Test: 464, score: 40.3 step: 10
# Test: 465, score: 40.3 step: 10
# Test: 466, score: 40.3 step: 10
# Test: 467, score: 40.3 step: 10
# Test: 468, score: 42.5 step: 20
# Test: 469, score: 40.3 step: 10
# Test: 470, score: 40.3 step: 10
# Test: 471, score: 40.3 step: 10
# Test: 472, score: 40.3 step: 10
# Test: 473, score: 42.5 step: 20
# Test: 474, score: 40.3 step: 10
# Test: 475, score: 40.3 step: 10
# Test: 476, score: 40.3 step: 10
# Test: 477, score: 40.3 step: 10
# Test: 478, score: 40.3 step: 10
# Test: 479, score: 40.3 step: 10
# Test: 480, score: 40.3 step: 10
# Test: 481, score: 40.3 step: 10
# Test: 482, score: 42.5 step: 20
# Test: 483, score: 40.3 step: 10
# Test: 484, score: 40.3 step: 10
# Test: 485, score: 40.3 step: 10
# Test: 486, score: 40.3 step: 10
# Test: 487, score: 40.3 step: 10
# Test: 488, score: 40.3 step: 10
# Test: 489, score: 40.3 step: 10
# Test: 490, score: 40.3 step: 10
# Test: 491, score: 40.3 step: 10
# Test: 492, score: 40.3 step: 10
# Test: 493, score: 40.3 step: 10
# Test: 494, score: 40.3 step: 10
# Test: 495, score: 40.3 step: 10
# Test: 496, score: 40.3 step: 10
# Test: 497, score: 40.3 step: 10
# Test: 498, score: 42.5 step: 20
# Test: 499, score: 40.3 step: 10
# Test: 500, score: 40.3 step: 10
# Test: 501, score: 40.3 step: 10
# Test: 502, score: 42.5 step: 20
# Test: 503, score: 40.3 step: 10
# Test: 504, score: 40.3 step: 10
# Test: 505, score: 40.3 step: 10
# Test: 506, score: 40.3 step: 10
# Test: 507, score: 40.3 step: 10
# Test: 508, score: 40.3 step: 10
# Test: 509, score: 40.3 step: 10
# Test: 510, score: 40.3 step: 10
# Test: 511, score: 40.3 step: 10
# Test: 512, score: 42.5 step: 20
# Test: 513, score: 42.5 step: 20
# Test: 514, score: 40.3 step: 10
# Test: 515, score: 42.5 step: 20
# Test: 516, score: 40.3 step: 10
# Test: 517, score: 40.3 step: 10
# Test: 518, score: 40.3 step: 10
# Test: 519, score: 40.3 step: 10
# Test: 520, score: 42.5 step: 20
# Test: 521, score: 40.3 step: 10
# Test: 522, score: 40.3 step: 10
# Test: 523, score: 40.3 step: 10
# Test: 524, score: 40.3 step: 10
# Test: 525, score: 42.5 step: 20
# Test: 526, score: 40.3 step: 10
# Test: 527, score: 40.3 step: 10
# Test: 528, score: 40.3 step: 10
# Test: 529, score: 40.3 step: 10
# Test: 530, score: 42.5 step: 20
# Test: 531, score: 42.5 step: 20
# Test: 532, score: 42.5 step: 20
# Test: 533, score: 40.3 step: 10
# Test: 534, score: 42.5 step: 20
# Test: 535, score: 40.3 step: 10
# Test: 536, score: 40.3 step: 10
# Test: 537, score: 40.3 step: 10
# Test: 538, score: 40.3 step: 10
# Test: 539, score: 40.3 step: 10
# Test: 540, score: 40.3 step: 10
# Test: 541, score: 40.3 step: 10
# Test: 542, score: 40.3 step: 10
# Test: 543, score: 40.3 step: 10
# Test: 544, score: 40.3 step: 10
# Test: 545, score: 40.3 step: 10
# Test: 546, score: 42.5 step: 20
# Test: 547, score: 40.3 step: 10
# Test: 548, score: 40.3 step: 10
# Test: 549, score: 42.5 step: 20
# Test: 550, score: 40.3 step: 10
# Test: 551, score: 40.3 step: 10
# Test: 552, score: 40.3 step: 10
# Test: 553, score: 42.5 step: 20
# Test: 554, score: 40.3 step: 10
# Test: 555, score: 40.3 step: 10
# Test: 556, score: 40.3 step: 10
# Test: 557, score: 40.3 step: 10
# Test: 558, score: 40.3 step: 10
# Test: 559, score: 42.5 step: 20
# Test: 560, score: 40.3 step: 10
# Test: 561, score: 40.3 step: 10
# Test: 562, score: 40.3 step: 10
# Test: 563, score: 42.5 step: 20
# Test: 564, score: 40.3 step: 10
# Test: 565, score: 42.5 step: 20
# Test: 566, score: 40.3 step: 10
# Test: 567, score: 40.3 step: 10
# Test: 568, score: 40.3 step: 10
# Test: 569, score: 40.3 step: 10
# Test: 570, score: 40.3 step: 10
# Test: 571, score: 40.3 step: 10
# Test: 572, score: 40.3 step: 10
# Test: 573, score: 40.3 step: 10
# Test: 574, score: 42.5 step: 20
# Test: 575, score: 42.5 step: 20
# Test: 576, score: 42.5 step: 20
# Test: 577, score: 40.3 step: 10
# Test: 578, score: 40.3 step: 10
# Test: 579, score: 42.5 step: 20
# Test: 580, score: 42.5 step: 20
# Test: 581, score: 42.5 step: 20
# Test: 582, score: 40.3 step: 10
# Test: 583, score: 40.3 step: 10
# Test: 584, score: 40.3 step: 10
# Test: 585, score: 40.3 step: 10
# Test: 586, score: 40.3 step: 10
# Test: 587, score: 40.3 step: 10
# Test: 588, score: 40.3 step: 10
# Test: 589, score: 42.5 step: 20
# Test: 590, score: 42.5 step: 20
# Test: 591, score: 40.3 step: 10
# Test: 592, score: 40.3 step: 10
# Test: 593, score: 40.3 step: 10
# Test: 594, score: 40.3 step: 10
# Test: 595, score: 40.3 step: 10
# Test: 596, score: 42.5 step: 20
# Test: 597, score: 42.5 step: 20
# Test: 598, score: 40.3 step: 10
# Test: 599, score: 42.5 step: 20
# Test: 600, score: 40.3 step: 10
# Test: 601, score: 40.3 step: 10
# Test: 602, score: 42.5 step: 20
# Test: 603, score: 40.3 step: 10
# Test: 604, score: 42.5 step: 20
# Test: 605, score: 40.3 step: 10
# Test: 606, score: 40.3 step: 10
# Test: 607, score: 40.3 step: 10
# Test: 608, score: 42.5 step: 20
# Test: 609, score: 40.3 step: 10
# Test: 610, score: 40.3 step: 10
# Test: 611, score: 42.5 step: 20
# Test: 612, score: 40.3 step: 10
# Test: 613, score: 40.3 step: 10
# Test: 614, score: 40.3 step: 10
# Test: 615, score: 40.3 step: 10
# Test: 616, score: 40.3 step: 10
# Test: 617, score: 42.5 step: 20
# Test: 618, score: 42.5 step: 20
# Test: 619, score: 42.5 step: 20
# Test: 620, score: 40.3 step: 10
# Test: 621, score: 40.3 step: 10
# Test: 622, score: 40.3 step: 10
# Test: 623, score: 42.5 step: 20
# Test: 624, score: 40.3 step: 10
# Test: 625, score: 42.5 step: 20
# Test: 626, score: 40.3 step: 10
# Test: 627, score: 42.5 step: 20
# Test: 628, score: 40.3 step: 10
# Test: 629, score: 40.3 step: 10
# Test: 630, score: 40.3 step: 10
# Test: 631, score: 40.3 step: 10
# Test: 632, score: 42.5 step: 20
# Test: 633, score: 40.3 step: 10
# Test: 634, score: 40.3 step: 10
# Test: 635, score: 42.5 step: 20
# Test: 636, score: 40.3 step: 10
# Test: 637, score: 40.3 step: 10
# Test: 638, score: 40.3 step: 10
# Test: 639, score: 40.3 step: 10
# Test: 640, score: 40.3 step: 10
# Test: 641, score: 40.3 step: 10
# Test: 642, score: 40.3 step: 10
# Test: 643, score: 40.3 step: 10
# Test: 644, score: 42.5 step: 20
# Test: 645, score: 40.3 step: 10
# Test: 646, score: 42.5 step: 20
# Test: 647, score: 40.3 step: 10
# Test: 648, score: 42.5 step: 20
# Test: 649, score: 40.3 step: 10
# Test: 650, score: 42.5 step: 20
# Test: 651, score: 40.3 step: 10
# Test: 652, score: 40.3 step: 10
# Test: 653, score: 40.3 step: 10
# Test: 654, score: 40.3 step: 10
# Test: 655, score: 40.3 step: 10
# Test: 656, score: 40.3 step: 10
# Test: 657, score: 40.3 step: 10
# Test: 658, score: 40.3 step: 10
# Test: 659, score: 40.3 step: 10
# Test: 660, score: 42.5 step: 20
# Test: 661, score: 40.3 step: 10
# Test: 662, score: 40.3 step: 10
# Test: 663, score: 40.3 step: 10
# Test: 664, score: 42.5 step: 20
# Test: 665, score: 40.3 step: 10
# Test: 666, score: 40.3 step: 10
# Test: 667, score: 40.3 step: 10
# Test: 668, score: 40.3 step: 10
# Test: 669, score: 40.3 step: 10
# Test: 670, score: 40.3 step: 10
# Test: 671, score: 40.3 step: 10
# Test: 672, score: 40.3 step: 10
# Test: 673, score: 42.5 step: 20
# Test: 674, score: 40.3 step: 10
# Test: 675, score: 40.3 step: 10
# Test: 676, score: 42.5 step: 20
# Test: 677, score: 42.5 step: 20
# Test: 678, score: 40.3 step: 10
# Test: 679, score: 40.3 step: 10
# Test: 680, score: 40.3 step: 10
# Test: 681, score: 40.3 step: 10
# Test: 682, score: 42.5 step: 20
# Test: 683, score: 40.3 step: 10
# Test: 684, score: 40.3 step: 10
# Test: 685, score: 40.3 step: 10
# Test: 686, score: 40.3 step: 10
# Test: 687, score: 40.3 step: 10
# Test: 688, score: 42.5 step: 20
# Test: 689, score: 40.3 step: 10
# Test: 690, score: 40.3 step: 10
# Test: 691, score: 40.3 step: 10
# Test: 692, score: 42.5 step: 20
# Test: 693, score: 40.3 step: 10
# Test: 694, score: 40.3 step: 10
# Test: 695, score: 40.3 step: 10
# Test: 696, score: 40.3 step: 10
# Test: 697, score: 40.3 step: 10
# Test: 698, score: 42.5 step: 20
# Test: 699, score: 40.3 step: 10
# Test: 700, score: 40.3 step: 10
# Test: 701, score: 40.3 step: 10
# Test: 702, score: 40.3 step: 10
# Test: 703, score: 42.5 step: 20
# Test: 704, score: 40.3 step: 10
# Test: 705, score: 40.3 step: 10
# Test: 706, score: 40.3 step: 10
# Test: 707, score: 40.3 step: 10
# Test: 708, score: 42.5 step: 20
# Test: 709, score: 40.3 step: 10
# Test: 710, score: 42.5 step: 20
# Test: 711, score: 40.3 step: 10
# Test: 712, score: 40.3 step: 10
# Test: 713, score: 40.3 step: 10
# Test: 714, score: 40.3 step: 10
# Test: 715, score: 40.3 step: 10
# Test: 716, score: 40.3 step: 10
# Test: 717, score: 40.3 step: 10
# Test: 718, score: 40.3 step: 10
# Test: 719, score: 42.5 step: 20
# Test: 720, score: 40.3 step: 10
# Test: 721, score: 42.5 step: 20
# Test: 722, score: 42.5 step: 20
# Test: 723, score: 40.3 step: 10
# Test: 724, score: 40.3 step: 10
# Test: 725, score: 42.5 step: 20
# Test: 726, score: 42.5 step: 20
# Test: 727, score: 40.3 step: 10
# Test: 728, score: 40.3 step: 10
# Test: 729, score: 40.3 step: 10
# Test: 730, score: 40.3 step: 10
# Test: 731, score: 40.3 step: 10
# Test: 732, score: 40.3 step: 10
# Test: 733, score: 40.3 step: 10
# Test: 734, score: 40.3 step: 10
# Test: 735, score: 40.3 step: 10
# Test: 736, score: 40.3 step: 10
# Test: 737, score: 42.5 step: 20
# Test: 738, score: 40.3 step: 10
# Test: 739, score: 40.3 step: 10
# Test: 740, score: 40.3 step: 10
# Test: 741, score: 40.3 step: 10
# Test: 742, score: 42.5 step: 20
# Test: 743, score: 40.3 step: 10
# Test: 744, score: 40.3 step: 10
# Test: 745, score: 42.5 step: 20
# Test: 746, score: 40.3 step: 10
# Test: 747, score: 42.5 step: 20
# Test: 748, score: 40.3 step: 10
# Test: 749, score: 40.3 step: 10
# Test: 750, score: 40.3 step: 10
# Test: 751, score: 40.3 step: 10
# Test: 752, score: 40.3 step: 10
# Test: 753, score: 40.3 step: 10
# Test: 754, score: 40.3 step: 10
# Test: 755, score: 40.3 step: 10
# Test: 756, score: 42.5 step: 20
# Test: 757, score: 40.3 step: 10
# Test: 758, score: 40.3 step: 10
# Test: 759, score: 40.3 step: 10
# Test: 760, score: 42.5 step: 20
# Test: 761, score: 40.3 step: 10
# Test: 762, score: 40.3 step: 10
# Test: 763, score: 42.5 step: 20
# Test: 764, score: 40.3 step: 10
# Test: 765, score: 40.3 step: 10
# Test: 766, score: 42.5 step: 20
# Test: 767, score: 40.3 step: 10
# Test: 768, score: 40.3 step: 10
# Test: 769, score: 40.3 step: 10
# Test: 770, score: 42.5 step: 20
# Test: 771, score: 40.3 step: 10
# Test: 772, score: 40.3 step: 10
# Test: 773, score: 42.5 step: 20
# Test: 774, score: 40.3 step: 10
# Test: 775, score: 40.3 step: 10
# Test: 776, score: 40.3 step: 10
# Test: 777, score: 40.3 step: 10
# Test: 778, score: 40.3 step: 10
# Test: 779, score: 40.3 step: 10
# Test: 780, score: 40.3 step: 10
# Test: 781, score: 42.5 step: 20
# Test: 782, score: 42.5 step: 20
# Test: 783, score: 40.3 step: 10
# Test: 784, score: 42.5 step: 20
# Test: 785, score: 40.3 step: 10
# Test: 786, score: 40.3 step: 10
# Test: 787, score: 40.3 step: 10
# Test: 788, score: 40.3 step: 10
# Test: 789, score: 40.3 step: 10
# Test: 790, score: 40.3 step: 10
# Test: 791, score: 40.3 step: 10
# Test: 792, score: 40.3 step: 10
# Test: 793, score: 40.3 step: 10
# Test: 794, score: 42.5 step: 20
# Test: 795, score: 40.3 step: 10
# Test: 796, score: 40.3 step: 10
# Test: 797, score: 40.3 step: 10
# Test: 798, score: 40.3 step: 10
# Test: 799, score: 42.5 step: 20
# Test: 800, score: 40.3 step: 10
# Test: 801, score: 42.5 step: 20
# Test: 802, score: 40.3 step: 10
# Test: 803, score: 40.3 step: 10
# Test: 804, score: 40.3 step: 10
# Test: 805, score: 40.3 step: 10
# Test: 806, score: 42.5 step: 20
# Test: 807, score: 40.3 step: 10
# Test: 808, score: 40.3 step: 10
# Test: 809, score: 40.3 step: 10
# Test: 810, score: 40.3 step: 10
# Test: 811, score: 40.3 step: 10
# Test: 812, score: 40.3 step: 10
# Test: 813, score: 40.3 step: 10
# Test: 814, score: 40.3 step: 10
# Test: 815, score: 40.3 step: 10
# Test: 816, score: 40.3 step: 10
# Test: 817, score: 40.3 step: 10
# Test: 818, score: 40.3 step: 10
# Test: 819, score: 40.3 step: 10
# Test: 820, score: 40.3 step: 10
# Test: 821, score: 40.3 step: 10
# Test: 822, score: 42.5 step: 20
# Test: 823, score: 42.5 step: 20
# Test: 824, score: 40.3 step: 10
# Test: 825, score: 40.3 step: 10
# Test: 826, score: 40.3 step: 10
# Test: 827, score: 42.5 step: 20
# Test: 828, score: 40.3 step: 10
# Test: 829, score: 40.3 step: 10
# Test: 830, score: 40.3 step: 10
# Test: 831, score: 40.3 step: 10
# Test: 832, score: 42.5 step: 20
# Test: 833, score: 40.3 step: 10
# Test: 834, score: 42.5 step: 20
# Test: 835, score: 40.3 step: 10
# Test: 836, score: 40.3 step: 10
# Test: 837, score: 40.3 step: 10
# Test: 838, score: 40.3 step: 10
# Test: 839, score: 40.3 step: 10
# Test: 840, score: 40.3 step: 10
# Test: 841, score: 40.3 step: 10
# Test: 842, score: 40.3 step: 10
# Test: 843, score: 42.5 step: 20
# Test: 844, score: 40.3 step: 10
# Test: 845, score: 40.3 step: 10
# Test: 846, score: 40.3 step: 10
# Test: 847, score: 42.5 step: 20
# Test: 848, score: 40.3 step: 10
# Test: 849, score: 42.5 step: 20
# Test: 850, score: 42.5 step: 20
# Test: 851, score: 40.3 step: 10
# Test: 852, score: 40.3 step: 10
# Test: 853, score: 42.5 step: 20
# Test: 854, score: 40.3 step: 10
# Test: 855, score: 40.3 step: 10
# Test: 856, score: 40.3 step: 10
# Test: 857, score: 40.3 step: 10
# Test: 858, score: 40.3 step: 10
# Test: 859, score: 42.5 step: 20
# Test: 860, score: 40.3 step: 10
# Test: 861, score: 42.5 step: 20
# Test: 862, score: 40.3 step: 10
# Test: 863, score: 40.3 step: 10
# Test: 864, score: 40.3 step: 10
# Test: 865, score: 40.3 step: 10
# Test: 866, score: 40.3 step: 10
# Test: 867, score: 40.3 step: 10
# Test: 868, score: 40.3 step: 10
# Test: 869, score: 42.5 step: 20
# Test: 870, score: 40.3 step: 10
# Test: 871, score: 42.5 step: 20
# Test: 872, score: 40.3 step: 10
# Test: 873, score: 42.5 step: 20
# Test: 874, score: 40.3 step: 10
# Test: 875, score: 40.3 step: 10
# Test: 876, score: 42.5 step: 20
# Test: 877, score: 40.3 step: 10
# Test: 878, score: 40.3 step: 10
# Test: 879, score: 40.3 step: 10
# Test: 880, score: 40.3 step: 10
# Test: 881, score: 42.5 step: 20
# Test: 882, score: 40.3 step: 10
# Test: 883, score: 40.3 step: 10
# Test: 884, score: 40.3 step: 10
# Test: 885, score: 40.3 step: 10
# Test: 886, score: 42.5 step: 20
# Test: 887, score: 40.3 step: 10
# Test: 888, score: 40.3 step: 10
# Test: 889, score: 40.3 step: 10
# Test: 890, score: 42.5 step: 20
# Test: 891, score: 42.5 step: 20
# Test: 892, score: 42.5 step: 20
# Test: 893, score: 42.5 step: 20
# Test: 894, score: 40.3 step: 10
# Test: 895, score: 40.3 step: 10
# Test: 896, score: 40.3 step: 10
# Test: 897, score: 40.3 step: 10
# Test: 898, score: 40.3 step: 10
# Test: 899, score: 40.3 step: 10
# Test: 900, score: 40.3 step: 10
# Test: 901, score: 42.5 step: 20
# Test: 902, score: 40.3 step: 10
# Test: 903, score: 40.3 step: 10
# Test: 904, score: 42.5 step: 20
# Test: 905, score: 40.3 step: 10
# Test: 906, score: 42.5 step: 20
# Test: 907, score: 40.3 step: 10
# Test: 908, score: 40.3 step: 10
# Test: 909, score: 42.5 step: 20
# Test: 910, score: 42.5 step: 20
# Test: 911, score: 40.3 step: 10
# Test: 912, score: 40.3 step: 10
# Test: 913, score: 40.3 step: 10
# Test: 914, score: 40.3 step: 10
# Test: 915, score: 42.5 step: 20
# Test: 916, score: 40.3 step: 10
# Test: 917, score: 40.3 step: 10
# Test: 918, score: 40.3 step: 10
# Test: 919, score: 40.3 step: 10
# Test: 920, score: 40.3 step: 10
# Test: 921, score: 42.5 step: 20
# Test: 922, score: 40.3 step: 10
# Test: 923, score: 42.5 step: 20
# Test: 924, score: 42.5 step: 20
# Test: 925, score: 40.3 step: 10
# Test: 926, score: 40.3 step: 10
# Test: 927, score: 40.3 step: 10
# Test: 928, score: 40.3 step: 10
# Test: 929, score: 40.3 step: 10
# Test: 930, score: 42.5 step: 20
# Test: 931, score: 40.3 step: 10
# Test: 932, score: 40.3 step: 10
# Test: 933, score: 40.3 step: 10
# Test: 934, score: 42.5 step: 20
# Test: 935, score: 40.3 step: 10
# Test: 936, score: 40.3 step: 10
# Test: 937, score: 40.3 step: 10
# Test: 938, score: 42.5 step: 20
# Test: 939, score: 40.3 step: 10
# Test: 940, score: 40.3 step: 10
# Test: 941, score: 42.5 step: 20
# Test: 942, score: 40.3 step: 10
# Test: 943, score: 40.3 step: 10
# Test: 944, score: 42.5 step: 20
# Test: 945, score: 40.3 step: 10
# Test: 946, score: 40.3 step: 10
# Test: 947, score: 40.3 step: 10
# Test: 948, score: 40.3 step: 10
# Test: 949, score: 40.3 step: 10
# Test: 950, score: 40.3 step: 10
# Test: 951, score: 40.3 step: 10
# Test: 952, score: 40.3 step: 10
# Test: 953, score: 40.3 step: 10
# Test: 954, score: 40.3 step: 10
# Test: 955, score: 40.3 step: 10
# Test: 956, score: 42.5 step: 20
# Test: 957, score: 42.5 step: 20
# Test: 958, score: 40.3 step: 10
# Test: 959, score: 42.5 step: 20
# Test: 960, score: 42.5 step: 20
# Test: 961, score: 40.3 step: 10
# Test: 962, score: 42.5 step: 20
# Test: 963, score: 42.5 step: 20
# Test: 964, score: 40.3 step: 10
# Test: 965, score: 40.3 step: 10
# Test: 966, score: 40.3 step: 10
# Test: 967, score: 40.3 step: 10
# Test: 968, score: 40.3 step: 10
# Test: 969, score: 40.3 step: 10
# Test: 970, score: 40.3 step: 10
# Test: 971, score: 42.5 step: 20
# Test: 972, score: 40.3 step: 10
# Test: 973, score: 42.5 step: 20
# Test: 974, score: 42.5 step: 20
# Test: 975, score: 40.3 step: 10
# Test: 976, score: 40.3 step: 10
# Test: 977, score: 40.3 step: 10
# Test: 978, score: 42.5 step: 20
# Test: 979, score: 40.3 step: 10
# Test: 980, score: 40.3 step: 10
# Test: 981, score: 40.3 step: 10
# Test: 982, score: 42.5 step: 20
# Test: 983, score: 40.3 step: 10
# Test: 984, score: 40.3 step: 10
# Test: 985, score: 42.5 step: 20
# Test: 986, score: 40.3 step: 10
# Test: 987, score: 40.3 step: 10
# Test: 988, score: 42.5 step: 20
# Test: 989, score: 40.3 step: 10
# Test: 990, score: 42.5 step: 20
# Test: 991, score: 40.3 step: 10
# Test: 992, score: 40.3 step: 10
# Test: 993, score: 40.3 step: 10
# Test: 994, score: 40.3 step: 10
# Test: 995, score: 40.3 step: 10
# Test: 996, score: 42.5 step: 20
# Test: 997, score: 40.3 step: 10
# Test: 998, score: 40.3 step: 10
# Test: 999, score: 42.5 step: 20
# Test: 1000, score: 40.3 step: 10
# Test: 1001, score: 40.3 step: 10
# Test: 1002, score: 40.3 step: 10
# Test: 1003, score: 42.5 step: 20
# Test: 1004, score: 40.3 step: 10
# Test: 1005, score: 40.3 step: 10
# Test: 1006, score: 40.3 step: 10
# Test: 1007, score: 40.3 step: 10
# Test: 1008, score: 42.5 step: 20
# Test: 1009, score: 40.3 step: 10
# Test: 1010, score: 40.3 step: 10
# Test: 1011, score: 42.5 step: 20
# Test: 1012, score: 40.3 step: 10
# Test: 1013, score: 40.3 step: 10
# Test: 1014, score: 40.3 step: 10
# Test: 1015, score: 40.3 step: 10
# Test: 1016, score: 42.5 step: 20
# Test: 1017, score: 40.3 step: 10
# Test: 1018, score: 40.3 step: 10
# Test: 1019, score: 40.3 step: 10
# Test: 1020, score: 40.3 step: 10
# Test: 1021, score: 40.3 step: 10
# Test: 1022, score: 40.3 step: 10
# Test: 1023, score: 42.5 step: 20
# Test: 1024, score: 42.5 step: 20
# Test: 1025, score: 40.3 step: 10
# Test: 1026, score: 42.5 step: 20
# Test: 1027, score: 42.5 step: 20
# Test: 1028, score: 42.5 step: 20
# Test: 1029, score: 40.3 step: 10
# Test: 1030, score: 40.3 step: 10
# Test: 1031, score: 40.3 step: 10
# Test: 1032, score: 42.5 step: 20
# Test: 1033, score: 40.3 step: 10
# Test: 1034, score: 40.3 step: 10
# Test: 1035, score: 40.3 step: 10
# Test: 1036, score: 40.3 step: 10
# Test: 1037, score: 40.3 step: 10
# Test: 1038, score: 42.5 step: 20
# Test: 1039, score: 40.3 step: 10
# Test: 1040, score: 40.3 step: 10
# Test: 1041, score: 40.3 step: 10
# Test: 1042, score: 42.5 step: 20
# Test: 1043, score: 40.3 step: 10
# Test: 1044, score: 42.5 step: 20
# Test: 1045, score: 40.3 step: 10
# Test: 1046, score: 40.3 step: 10
# Test: 1047, score: 40.3 step: 10
# Test: 1048, score: 42.5 step: 20
# Test: 1049, score: 42.5 step: 20
# Test: 1050, score: 40.3 step: 10
# Test: 1051, score: 42.5 step: 20
# Test: 1052, score: 40.3 step: 10
# Test: 1053, score: 40.3 step: 10
# Test: 1054, score: 40.3 step: 10
# Test: 1055, score: 42.5 step: 20
# Test: 1056, score: 40.3 step: 10
# Test: 1057, score: 40.3 step: 10
# Test: 1058, score: 42.5 step: 20
# Test: 1059, score: 40.3 step: 10
# Test: 1060, score: 42.5 step: 20
# Test: 1061, score: 40.3 step: 10
# Test: 1062, score: 40.3 step: 10
# Test: 1063, score: 40.3 step: 10
# Test: 1064, score: 40.3 step: 10
# Test: 1065, score: 42.5 step: 20
# Test: 1066, score: 42.5 step: 20
# Test: 1067, score: 40.3 step: 10
# Test: 1068, score: 40.3 step: 10
# Test: 1069, score: 40.3 step: 10
# Test: 1070, score: 40.3 step: 10
# Test: 1071, score: 42.5 step: 20
# Test: 1072, score: 40.3 step: 10
# Test: 1073, score: 40.3 step: 10
# Test: 1074, score: 40.3 step: 10
# Test: 1075, score: 42.5 step: 20
# Test: 1076, score: 40.3 step: 10
# Test: 1077, score: 42.5 step: 20
# Test: 1078, score: 40.3 step: 10
# Test: 1079, score: 42.5 step: 20
# Test: 1080, score: 40.3 step: 10
# Test: 1081, score: 42.5 step: 20
# Test: 1082, score: 40.3 step: 10
# Test: 1083, score: 40.3 step: 10
# Test: 1084, score: 40.3 step: 10
# Test: 1085, score: 40.3 step: 10
# Test: 1086, score: 40.3 step: 10
# Test: 1087, score: 40.3 step: 10
# Test: 1088, score: 40.3 step: 10
# Test: 1089, score: 40.3 step: 10
# Test: 1090, score: 42.5 step: 20
# Test: 1091, score: 40.3 step: 10
# Test: 1092, score: 42.5 step: 20
# Test: 1093, score: 40.3 step: 10
# Test: 1094, score: 40.3 step: 10
# Test: 1095, score: 40.3 step: 10
# Test: 1096, score: 42.5 step: 20
# Test: 1097, score: 40.3 step: 10
# Test: 1098, score: 40.3 step: 10
# Test: 1099, score: 40.3 step: 10
# Test: 1100, score: 42.5 step: 20
# Test: 1101, score: 40.3 step: 10
# Test: 1102, score: 40.3 step: 10
# Test: 1103, score: 40.3 step: 10
# Test: 1104, score: 40.3 step: 10
# Test: 1105, score: 40.3 step: 10
# Test: 1106, score: 40.3 step: 10
# Test: 1107, score: 40.3 step: 10
# Test: 1108, score: 40.3 step: 10
# Test: 1109, score: 42.5 step: 20
# Test: 1110, score: 40.3 step: 10
# Test: 1111, score: 40.3 step: 10
# Test: 1112, score: 40.3 step: 10
# Test: 1113, score: 42.5 step: 20
# Test: 1114, score: 40.3 step: 10
# Test: 1115, score: 40.3 step: 10
# Test: 1116, score: 40.3 step: 10
# Test: 1117, score: 40.3 step: 10
# Test: 1118, score: 40.3 step: 10
# Test: 1119, score: 40.3 step: 10
# Test: 1120, score: 40.3 step: 10
# Test: 1121, score: 42.5 step: 20
# Test: 1122, score: 40.3 step: 10
# Test: 1123, score: 40.3 step: 10
# Test: 1124, score: 40.3 step: 10
# Test: 1125, score: 40.3 step: 10
# Test: 1126, score: 40.3 step: 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-db2922b9af4f> in <module>
#     196 if __name__ == "__main__":
#     197     #cartpole()
# --> 198     cartpole_test()
#
# <ipython-input-1-db2922b9af4f> in cartpole_test()
#     151             step += 1
#     152             action = np.argmax(model.predict(state)[0])
# --> 153             observe_past, reward, total_reward, state_next, terminal = env.step(action)
#     154             state_next = np.reshape(state_next, [1, observation_space])
#     155             state = state_next
#
# ~/Desktop/folder/public_transport/GridWorld/environment/environment.py in step(self, action)
#     216         #self.final_reward = 5
#     217
# --> 218         new_state = self.grid
#     219         self.run_frame()
#     220         self.total_reward += self.reward
#
# ~/Desktop/folder/public_transport/GridWorld/environment/environment.py in run_frame(self)
#     226             fr.runner((self.grid), (self.agent_pos), (self.target_pos), (self.timestep), (self.transport_timetable),
#     227                   (self.target_missed), (self.target_achieved), (self.n_iteration),
# --> 228                   (self.frame_second), (self.reward), (self.final_reward), (self.action_performed),
#     229                   (self.total_reward), debug_mode=(self.debug_mode))
#     230         if self.agent_pos == self.target_pos:
#
# ~/Desktop/folder/public_transport/GridWorld/environment/frame_runner.py in runner(grid, agent_pos, target_pos, timestep, transport_timetable, n_missed, n_achieved, n_iteration, frame_second, reward_action, possible_reward, action_performed, total_reward, debug_mode)
#      67     write('Time: '+str(timestep), 100, 10)
#      68     write('Iteration: '+str(n_iteration), 200, 10)
# ---> 69     write('Missed: '+str(n_missed), 300, 10)
#      70     write('Achieved: '+str(n_achieved), 400, 10)
#      71     write('Reward_action: '+str(reward_action)[:5], 550, 10)
#
# ~/Desktop/folder/public_transport/GridWorld/environment/frame_runner.py in write(text, x, y)
#      45
#      46     def write(text, x, y):
# ---> 47         font = pygame.font.Font('freesansbold.ttf', 15)
#      48         text = font.render(text, True, WHITE, RED)
#      49         textRect = text.get_rect()
#
# ~/anaconda3/envs/lorenzo_env/lib/python3.6/site-packages/pygame/pkgdata.py in getResource(identifier, pkgname)
#      32         raise NotImplementedError
#      33
# ---> 34 def getResource(identifier, pkgname=__name__):
#      35     """
#      36     Acquire a readable object for a given package name and identifier.
#
# KeyboardInterrupt:

# %%
import random
random.randint(0,1)
